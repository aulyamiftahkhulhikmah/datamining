# %% [markdown]
# # TUGAS 7 Regretion Linear

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=150, n_features=1, noise=0.2)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([78.57355197])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
#python code demonstrate creating
#DataFrame from dict narray/ lists
#By default addresses.

import pandas as pd
data={'X':x,
      'y':y}

#Create DataFrame
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X          y
# 0    [-2.4271889603808896] -63.815086
# 1     [1.4570108477542867]  37.991044
# 2   [-0.37889875180057286]  -9.950894
# 3     [1.1344604792790118]  29.716765
# 4     [0.3383255304845661]   9.005902
# 5     [0.8687469200660942]  22.673863
# 6     [0.9757813654438962]  25.837757
# 7     [1.2697964223381533]  33.506576
# 8     [0.9859838879931403]  25.615245
# 9    [0.32852672868218036]   8.546192
# 10    [0.5780411076157941]  15.097408
# 11    [0.6816207719055113]  17.821214
# 12   [0.10474590557734685]   2.452465
# 13   [-1.6047832612374466] -41.976003
# 14     [1.061151307238244]  27.743382
# 15   [-0.1322803196106797]  -3.681868
# 16    [0.0101237564748485]   0.465582
# 17     [0.589923244896972]  15.308196
# 18     [2.024646984480875]  52.940524
# 19   [-0.8243070595950167] -21.726511

# %%
reg.coef_
# Out:
# array([26.18875057])

# %%
reg.intercept_
# Out:
# 0.007300252261143836

# %%
pyplot.scatter(X_test,y_test)
y_plot = reg.coef_*X_test+reg.intercept_

pyplot.plot(X_test, y_plot, color='r')

pyplot.show()
